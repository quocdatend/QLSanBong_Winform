-- %% [markdown]
-- # [QLSanBongDaMini]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [QLSanBongDaMini]    Script Date: 26/08/2024 11:04:04 CH ******/
CREATE DATABASE [QLSanBongDaMini]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'QLSanBongDaMini', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\QLSanBongDaMini.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'QLSanBongDaMini_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\QLSanBongDaMini_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [QLSanBongDaMini] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [QLSanBongDaMini].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [QLSanBongDaMini] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET ARITHABORT OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [QLSanBongDaMini] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [QLSanBongDaMini] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET  DISABLE_BROKER 
GO
ALTER DATABASE [QLSanBongDaMini] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [QLSanBongDaMini] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [QLSanBongDaMini] SET  MULTI_USER 
GO
ALTER DATABASE [QLSanBongDaMini] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [QLSanBongDaMini] SET DB_CHAINING OFF 
GO
ALTER DATABASE [QLSanBongDaMini] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [QLSanBongDaMini] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [QLSanBongDaMini] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [QLSanBongDaMini] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [QLSanBongDaMini] SET QUERY_STORE = ON
GO
ALTER DATABASE [QLSanBongDaMini] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [quocdat123]

-- %%
USE [QLSanBongDaMini]
GO

-- %%
/****** Object:  User [quocdat123]    Script Date: 26/08/2024 11:04:05 CH ******/
CREATE USER [quocdat123] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[quocdat123]
GO

-- %% [markdown]
-- # [quocdat]

-- %%
/****** Object:  User [quocdat]    Script Date: 26/08/2024 11:04:05 CH ******/
CREATE USER [quocdat] WITHOUT LOGIN WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [quocdat123]

-- %%
/****** Object:  Schema [quocdat123]    Script Date: 26/08/2024 11:04:05 CH ******/
CREATE SCHEMA [quocdat123]
GO

-- %% [markdown]
-- # [dbo].[ADMIN]

-- %%
/****** Object:  Table [dbo].[ADMIN]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ADMIN](
	[NAME] [nvarchar](20) NOT NULL,
	[PASS] [char](64) NOT NULL,
	[EMAIL] [nvarchar](255) NOT NULL,
	[ID] [int] IDENTITY(1,1) NOT NULL,
 CONSTRAINT [PK_ADMIN] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ADMIN_ROLE]

-- %%
/****** Object:  Table [dbo].[ADMIN_ROLE]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ADMIN_ROLE](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ADMIN_ID] [int] NOT NULL,
	[ROLE_ID] [int] NOT NULL,
 CONSTRAINT [PK_ADMIN_ROLE] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FOOD_DRINK]

-- %%
/****** Object:  Table [dbo].[FOOD_DRINK]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FOOD_DRINK](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](30) NOT NULL,
	[COUNT] [int] NOT NULL,
	[PRICE] [float] NOT NULL,
	[URL_IMG] [nvarchar](255) NULL,
 CONSTRAINT [PK_FOOD_DRINK] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ORDER_FOOD_DRINK]

-- %%
/****** Object:  Table [dbo].[ORDER_FOOD_DRINK]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ORDER_FOOD_DRINK](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USER_ID] [int] NOT NULL,
	[TIME] [datetime] NOT NULL,
 CONSTRAINT [PK_ORDER_FOOD_DRINK_DETAIL] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ORDER_FOOD_DRINK_DETAIL]

-- %%
/****** Object:  Table [dbo].[ORDER_FOOD_DRINK_DETAIL]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ORDER_FOOD_DRINK_DETAIL](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[FOOD_DRINK_ID] [int] NOT NULL,
	[ORDER_FOOD_DRINK_ID] [int] NOT NULL,
	[COUNT] [int] NOT NULL,
	[PRICE] [float] NOT NULL,
 CONSTRAINT [PK_ORDER_FOOD_DRINK_DETAIL_1] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ORDER_PITCH]

-- %%
/****** Object:  Table [dbo].[ORDER_PITCH]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ORDER_PITCH](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PITCH_ID] [int] NOT NULL,
	[USER_ID] [int] NOT NULL,
	[TIME_START] [datetime] NOT NULL,
	[TIME_END] [datetime] NOT NULL,
	[PRICE] [float] NOT NULL,
	[IS_CHECK] [bit] NULL,
	[PRICE_PER_HOUR_ID] [int] NOT NULL,
	[IS_PAY] [bit] NOT NULL,
	[IS_CANCEL] [bit] NULL,
 CONSTRAINT [PK_ORDER_PITCH] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PAYMENT_HISTORY]

-- %%
/****** Object:  Table [dbo].[PAYMENT_HISTORY]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PAYMENT_HISTORY](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PRICE] [float] NOT NULL,
	[TIME] [datetime] NOT NULL,
	[USER_ID] [int] NOT NULL,
	[ORDER_PITCH_ID] [int] NULL,
	[ORDER_FOOD_DRINK_ID] [int] NULL,
	[IS_CHECK] [bit] NULL,
 CONSTRAINT [PK_PAYMENT_HISTORY] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PITCH]

-- %%
/****** Object:  Table [dbo].[PITCH]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PITCH](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](30) NOT NULL,
	[TYPE_PITCH_ID] [int] NOT NULL,
 CONSTRAINT [PK_PITCH] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PRICE_PER_HOUR]

-- %%
/****** Object:  Table [dbo].[PRICE_PER_HOUR]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PRICE_PER_HOUR](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TIME_START] [time](7) NOT NULL,
	[TIME_END] [time](7) NOT NULL,
	[PRICE] [float] NOT NULL,
 CONSTRAINT [PK_PRICE_PER_HOUR] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ROLE]

-- %%
/****** Object:  Table [dbo].[ROLE]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ROLE](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [char](5) NOT NULL,
 CONSTRAINT [PK_ROLE] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TYPE_PITCH]

-- %%
/****** Object:  Table [dbo].[TYPE_PITCH]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TYPE_PITCH](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[NAME] [nvarchar](10) NOT NULL,
	[PRICE] [float] NOT NULL,
 CONSTRAINT [PK_TYPE_PITCH] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USER_ROLE]

-- %%
/****** Object:  Table [dbo].[USER_ROLE]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USER_ROLE](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USER_ID] [int] NOT NULL,
	[ROLE_ID] [int] NOT NULL,
 CONSTRAINT [PK_USER_ROLE] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USERS]

-- %%
/****** Object:  Table [dbo].[USERS]    Script Date: 26/08/2024 11:04:05 CH ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USERS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USERNAME] [nvarchar](50) NOT NULL,
	[PASS] [char](64) NOT NULL,
	[PHONE] [char](11) NOT NULL,
	[EMAIL] [nvarchar](255) NOT NULL,
 CONSTRAINT [PK_USERS] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_ORDER_PITCH_IS_CHECK_1]

-- %%
ALTER TABLE [dbo].[ORDER_PITCH] ADD  CONSTRAINT [DF_ORDER_PITCH_IS_CHECK_1]  DEFAULT ((0)) FOR [IS_CHECK]
GO

-- %% [markdown]
-- # [DF_ORDER_PITCH_IS_PAY]

-- %%
ALTER TABLE [dbo].[ORDER_PITCH] ADD  CONSTRAINT [DF_ORDER_PITCH_IS_PAY]  DEFAULT ((0)) FOR [IS_PAY]
GO

-- %% [markdown]
-- # [FK_ADMIN_ROLE_ADMIN]

-- %%
ALTER TABLE [dbo].[ADMIN_ROLE]  WITH CHECK ADD  CONSTRAINT [FK_ADMIN_ROLE_ADMIN] FOREIGN KEY([ADMIN_ID])
REFERENCES [dbo].[ADMIN] ([ID])
GO
ALTER TABLE [dbo].[ADMIN_ROLE] CHECK CONSTRAINT [FK_ADMIN_ROLE_ADMIN]
GO

-- %% [markdown]
-- # [FK_ADMIN_ROLE_ROLE]

-- %%
ALTER TABLE [dbo].[ADMIN_ROLE]  WITH CHECK ADD  CONSTRAINT [FK_ADMIN_ROLE_ROLE] FOREIGN KEY([ROLE_ID])
REFERENCES [dbo].[ROLE] ([ID])
GO
ALTER TABLE [dbo].[ADMIN_ROLE] CHECK CONSTRAINT [FK_ADMIN_ROLE_ROLE]
GO

-- %% [markdown]
-- # [FK_ORDER_FOOD_DRINK_DETAIL_USERS]

-- %%
ALTER TABLE [dbo].[ORDER_FOOD_DRINK]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_USERS] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[ORDER_FOOD_DRINK] CHECK CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_USERS]
GO

-- %% [markdown]
-- # [FK_ORDER_FOOD_DRINK_DETAIL_FOOD_DRINK1]

-- %%
ALTER TABLE [dbo].[ORDER_FOOD_DRINK_DETAIL]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_FOOD_DRINK1] FOREIGN KEY([FOOD_DRINK_ID])
REFERENCES [dbo].[FOOD_DRINK] ([ID])
GO
ALTER TABLE [dbo].[ORDER_FOOD_DRINK_DETAIL] CHECK CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_FOOD_DRINK1]
GO

-- %% [markdown]
-- # [FK_ORDER_FOOD_DRINK_DETAIL_ORDER_FOOD_DRINK]

-- %%
ALTER TABLE [dbo].[ORDER_FOOD_DRINK_DETAIL]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_ORDER_FOOD_DRINK] FOREIGN KEY([ORDER_FOOD_DRINK_ID])
REFERENCES [dbo].[ORDER_FOOD_DRINK] ([ID])
GO
ALTER TABLE [dbo].[ORDER_FOOD_DRINK_DETAIL] CHECK CONSTRAINT [FK_ORDER_FOOD_DRINK_DETAIL_ORDER_FOOD_DRINK]
GO

-- %% [markdown]
-- # [FK_ORDER_PITCH_PITCH]

-- %%
ALTER TABLE [dbo].[ORDER_PITCH]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_PITCH_PITCH] FOREIGN KEY([PITCH_ID])
REFERENCES [dbo].[PITCH] ([ID])
GO
ALTER TABLE [dbo].[ORDER_PITCH] CHECK CONSTRAINT [FK_ORDER_PITCH_PITCH]
GO

-- %% [markdown]
-- # [FK_ORDER_PITCH_PRICE_PER_HOUR]

-- %%
ALTER TABLE [dbo].[ORDER_PITCH]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_PITCH_PRICE_PER_HOUR] FOREIGN KEY([PRICE_PER_HOUR_ID])
REFERENCES [dbo].[PRICE_PER_HOUR] ([ID])
GO
ALTER TABLE [dbo].[ORDER_PITCH] CHECK CONSTRAINT [FK_ORDER_PITCH_PRICE_PER_HOUR]
GO

-- %% [markdown]
-- # [FK_ORDER_PITCH_USERS]

-- %%
ALTER TABLE [dbo].[ORDER_PITCH]  WITH CHECK ADD  CONSTRAINT [FK_ORDER_PITCH_USERS] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[ORDER_PITCH] CHECK CONSTRAINT [FK_ORDER_PITCH_USERS]
GO

-- %% [markdown]
-- # [FK_PAYMENT_HISTORY_ORDER_FOOD_DRINK]

-- %%
ALTER TABLE [dbo].[PAYMENT_HISTORY]  WITH CHECK ADD  CONSTRAINT [FK_PAYMENT_HISTORY_ORDER_FOOD_DRINK] FOREIGN KEY([ORDER_FOOD_DRINK_ID])
REFERENCES [dbo].[ORDER_FOOD_DRINK] ([ID])
GO
ALTER TABLE [dbo].[PAYMENT_HISTORY] CHECK CONSTRAINT [FK_PAYMENT_HISTORY_ORDER_FOOD_DRINK]
GO

-- %% [markdown]
-- # [FK_PAYMENT_HISTORY_ORDER_PITCH]

-- %%
ALTER TABLE [dbo].[PAYMENT_HISTORY]  WITH CHECK ADD  CONSTRAINT [FK_PAYMENT_HISTORY_ORDER_PITCH] FOREIGN KEY([ORDER_PITCH_ID])
REFERENCES [dbo].[ORDER_PITCH] ([ID])
GO
ALTER TABLE [dbo].[PAYMENT_HISTORY] CHECK CONSTRAINT [FK_PAYMENT_HISTORY_ORDER_PITCH]
GO

-- %% [markdown]
-- # [FK_PAYMENT_HISTORY_USERS]

-- %%
ALTER TABLE [dbo].[PAYMENT_HISTORY]  WITH CHECK ADD  CONSTRAINT [FK_PAYMENT_HISTORY_USERS] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[PAYMENT_HISTORY] CHECK CONSTRAINT [FK_PAYMENT_HISTORY_USERS]
GO

-- %% [markdown]
-- # [FK_PITCH_TYPE_PITCH]

-- %%
ALTER TABLE [dbo].[PITCH]  WITH CHECK ADD  CONSTRAINT [FK_PITCH_TYPE_PITCH] FOREIGN KEY([TYPE_PITCH_ID])
REFERENCES [dbo].[TYPE_PITCH] ([ID])
GO
ALTER TABLE [dbo].[PITCH] CHECK CONSTRAINT [FK_PITCH_TYPE_PITCH]
GO

-- %% [markdown]
-- # [FK_USER_ROLE_ROLE]

-- %%
ALTER TABLE [dbo].[USER_ROLE]  WITH CHECK ADD  CONSTRAINT [FK_USER_ROLE_ROLE] FOREIGN KEY([ROLE_ID])
REFERENCES [dbo].[ROLE] ([ID])
GO
ALTER TABLE [dbo].[USER_ROLE] CHECK CONSTRAINT [FK_USER_ROLE_ROLE]
GO

-- %% [markdown]
-- # [FK_USER_ROLE_USERS]

-- %%
ALTER TABLE [dbo].[USER_ROLE]  WITH CHECK ADD  CONSTRAINT [FK_USER_ROLE_USERS] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[USER_ROLE] CHECK CONSTRAINT [FK_USER_ROLE_USERS]
GO

-- %% [markdown]
-- # [QLSanBongDaMini]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [QLSanBongDaMini] SET  READ_WRITE 
GO
